# %% [markdown]
# <a href="https://colab.research.google.com/github/blancavazquez/CursoDatosMasivosII/blob/master/notebooks/5d_conteo_triangulos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Conteo de triángulos
#
# El objetivo de esta libreta es emplear el algoritmo de conteo de triángulos usando las funciones de agrupamiento de la biblioteca de [Networkx](https://networkx.org/documentation/stable/reference/algorithms/clustering.html)

# %%
"""Carga de bibliotecas"""
from numpy import array
import networkx as nx
import numpy as np

# %% [markdown]
# ## Ejemplo básico

# %%
G = nx.complete_graph(4)
nx.draw(G, with_labels = True) #Visualizamos el grafo
print(list(nx.triangles(G, (0, 1)).values()))
number_of_triangles = sum(nx.triangles(G).values()) / 3
print("Número de triángulos en el grafo: ", number_of_triangles)
# Out:
# [3, 3]
# Número de triángulos en el grafo:  4.0

# %%
#Diccionario con el número de enlaces por nodo
print(nx.triangles(G))
# Out:
# {0: 3, 1: 3, 2: 3, 3: 3}

# %%
G = nx.complete_graph(10)
nx.draw(G, with_labels = True) #Visualizamos el grafo
print(list(nx.triangles(G, (0, 1)).values()))
number_of_triangles = sum(nx.triangles(G).values()) / 3
print("Número de triángulos en el grafo: ", number_of_triangles)
# Out:
# [36, 36]
# Número de triángulos en el grafo:  120.0

# %% [markdown]
# ## Detección de comunidades con conteo de triángulos

# %%
G = nx.karate_club_graph()

# %%
pos = nx.kamada_kawai_layout(G)

# %%
number_of_triangles = sum(nx.triangles(G).values()) / 3
print("Número de triángulos en el grafo: ", number_of_triangles)
# Out:
# Número de triángulos en el grafo:  45.0

# %%
#Diccionario con el número de enlaces por nodo
print(nx.triangles(G))
# Out:
# {0: 18, 1: 12, 2: 11, 3: 10, 4: 2, 5: 3, 6: 3, 7: 6, 8: 5, 9: 0, 10: 2, 11: 0, 12: 1, 13: 6, 14: 1, 15: 1, 16: 1, 17: 1, 18: 1, 19: 1, 20: 1, 21: 1, 22: 1, 23: 4, 24: 1, 25: 1, 26: 1, 27: 1, 28: 1, 29: 4, 30: 3, 31: 3, 32: 13, 33: 15}

# %%
values = nx.triangles(G) #obteniendo el diccionario
n_color = np.asarray([values[n] for n in G.nodes()])
nx.draw(G, pos, node_color=n_color)
