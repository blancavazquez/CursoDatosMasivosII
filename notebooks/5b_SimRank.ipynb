# %% [markdown]
# <a href="https://colab.research.google.com/github/blancavazquez/CursoDatosMasivosII/blob/2023-I/notebooks/5b_SimRank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## SimRanK
#
# El objetivo de esta libreta es utilizar el algoritmo de SimRank para lo cual se empleará la biblioteca [simrank_similarity](https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.similarity.simrank_similarity.html) del módulo de networkx.

# %% [markdown]
# ### Ejemplo sencillo de SimRank

# %%
"""Carga de bibliotecas"""
from numpy import array
import networkx as nx

# %%
G = nx.cycle_graph(4)
nx.draw(G, with_labels = True) #Visualizamos el grafo

# %%
sim = nx.simrank_similarity(G,target = 2)

# %%
sim
# Out:
# {0: {0: 1.0, 1: 0.0, 2: 0.8181254024807277, 3: 0.0},
#  1: {0: 0.0, 1: 1.0, 2: 0.0, 3: 0.8181254024807277},
#  2: {0: 0.8181254024807277, 1: 0.0, 2: 1.0, 3: 0.0},
#  3: {0: 0.0, 1: 0.8181254024807277, 2: 0.0, 3: 1.0}}

# %%
from numpy import array
G = nx.karate_club_graph()
nx.draw(G, with_labels = True) #Visualizamos el grafo

# %%
sim = nx.simrank_similarity(G)

# %%
sim
# Out:
# {0: {0: 1.0,
#   1: 0.3259854404250346,
#   2: 0.2746096601905966,
#   3: 0.3188101172953541,
#   4: 0.3046595335530612,
#   5: 0.2912240241096662,
#   6: 0.29122402410966614,
#   7: 0.2937249271943831,
#   8: 0.23713232752149582,
#   9: 0.24691124252214494,
#   10: 0.3046595335530612,
#   11: 0.2513715315963902,
#   12: 0.28838930260573165,
#   13: 0.27472232874973374,
#   14: 0.19815335083478747,
#   15: 0.19815335083478747,
#   16: 0.32475648909160537,
#   17: 0.2771910425446528,
#   18: 0.19815335083478747,
#   19: 0.2510313400201472,
#   20: 0.19815335083478747,
#   21: 0.2771910425446528,
#   22: 0.19815335083478747,
#   23: 0.19883341352029507,
#   24: 0.22563079574755404,
#   25: 0.22313854379412346,
#   26: 0.19908176278057044,
#   27: 0.22118862613147344,
#   28: 0.2574353656483522,
#   29: 0.20017655716647334,
#   30: 0.2502778504929089,
#   31: 0.20810155584691303,
#   32: 0.23492645206530668,
#   33: 0.2408254173885561},
#  1: {0: 0.32598544042503463,
#   1: 1.0,
# ...
